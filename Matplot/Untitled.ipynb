# %%
import matplotlib.pyplot as plt

plt.axes([0.5,0.5,1,1])
plt.plot([0.1,0.2,0.3],[0.2,0.3,1.0],'blue')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.axes([0.0,0.2,1,1])
plt.plot([0.1,0.2,0.3],[0.2,0.3,1.0],'blue')
plt.show()
