# %%
import numpy as np
num_points = 300
vectors_set = []
for i in xrange(num_points):
  x = np.random.normal(5,5)+15
  y =  x*2+ (np.random.normal(0,3))*2
  vectors_set.append([x,y])
  
x_data = [v[0] for v in vectors_set ]
y_data = [v[1] for v in vectors_set ]

# %%
import matplotlib.pyplot as plt
plt.plot(x_data,y_data,'ro')
plt.ylim([0,100])
plt.xlim([5,35])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf

input_fn_train = tf.estimator.inputs.numpy_input_fn(
    x = {"x":np.array(x_data[:200],dtype=np.float32)},
    y = np.array(y_data[:200],dtype=np.float32),
    num_epochs=100000,
    batch_size=50,
    shuffle=True
)

input_fn_eval = tf.estimator.inputs.numpy_input_fn(
    x = {"x":np.array(x_data[200:300],dtype=np.float32)},
    y = np.array(y_data[200:300],dtype=np.float32),
    num_epochs=100000,
    batch_size=50,
    shuffle=True
)

input_fn_predict = tf.estimator.inputs.numpy_input_fn(
    x = {"x":np.array([15,20,25,30],dtype=np.float32)},
    num_epochs=1,
    shuffle=False
)
column_x = tf.feature_column.numeric_column("x",dtype=tf.float32)
columns = [column_x]

estimator = tf.contrib.learn.LinearRegressor(feature_columns=columns,optimizer="Adam")
estimator.fit(input_fn = input_fn_train,steps=5000)

estimator.evaluate(input_fn = input_fn_eval,steps=10)
result = list(estimator.predict(input_fn = input_fn_predict))

print (result)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x119bb7ad0>, '_model_dir': '/var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': None, '_save_summary_steps': 100, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_evaluation_master': '', '_master': ''}
# WARNING:tensorflow:From /Users/terrycho/anaconda/envs/tensorflow13/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:642: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe/model.ckpt.
# INFO:tensorflow:loss = 1889.22, step = 1
# INFO:tensorflow:global_step/sec: 1112.51
# INFO:tensorflow:loss = 24.5308, step = 101 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1066.32
# INFO:tensorflow:loss = 34.7926, step = 201 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1098.31
# INFO:tensorflow:loss = 20.951, step = 301 (0.092 sec)
# INFO:tensorflow:global_step/sec: 965.093
# INFO:tensorflow:loss = 31.9355, step = 401 (0.103 sec)
# INFO:tensorflow:global_step/sec: 1025.08
# INFO:tensorflow:loss = 28.0336, step = 501 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1082.79
# INFO:tensorflow:loss = 20.6413, step = 601 (0.092 sec)
# INFO:tensorflow:global_step/sec: 1060.73
# INFO:tensorflow:loss = 27.3869, step = 701 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1022.37
# INFO:tensorflow:loss = 28.3734, step = 801 (0.098 sec)
# INFO:tensorflow:global_step/sec: 
(0.096 sec)
# INFO:tensorflow:global_step/sec: 1008.56
# INFO:tensorflow:loss = 23.8406, step = 3501 (0.099 sec)
# INFO:tensorflow:global_step/sec: 920.031
# INFO:tensorflow:loss = 20.0992, step = 3601 (0.109 sec)
# INFO:tensorflow:global_step/sec: 931.219
# INFO:tensorflow:loss = 24.5315, step = 3701 (0.107 sec)
# INFO:tensorflow:global_step/sec: 1055.56
# INFO:tensorflow:loss = 38.3173, step = 3801 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1014.63
# INFO:tensorflow:loss = 14.934, step = 3901 (0.098 sec)
# INFO:tensorflow:global_step/sec: 986.194
# INFO:tensorflow:loss = 34.9171, step = 4001 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1010.88
# INFO:tensorflow:loss = 22.8846, step = 4101 (0.099 sec)
# INFO:tensorflow:global_step/sec: 1011.67
# INFO:tensorflow:loss = 27.9918, step = 4201 (0.099 sec)
# INFO:tensorflow:global_step/sec: 1066.68
# INFO:tensorflow:loss = 20.531, step = 4301 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1133.84
# INFO:tensorflow:loss = 33.6445, step = 4401 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1030.86
# INFO:tensorflow:loss = 18.8622, step = 4501 (0.097 sec)
# INFO:tensorflow:global_step/sec: 969.378
# INFO:tensorflow:loss = 21.8649, step = 4601 (0.103 sec)
# INFO:tensorflow:global_step/sec: 1074.42
# INFO:tensorflow:loss = 27.486, step = 4701 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1066.96
# INFO:tensorflow:loss = 20.1524, step = 4801 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1018.63
# INFO:tensorflow:loss = 26.3581, step = 4901 (0.098 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe/model.ckpt.
# INFO:tensorflow:Loss for final step: 31.5995.
# WARNING:tensorflow:From /Users/terrycho/anaconda/envs/tensorflow13/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:642: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-09-05-08:39:43
# INFO:tensorflow:Restoring parameters from /var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe/model.ckpt-5000
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2017-09-05-08:39:43
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 39.4649
# WARNING:tensorflow:From /Users/terrycho/anaconda/envs/tensorflow13/lib/python2.7/site-packages/tensorflow/python/util/deprecation.py:355: calling predict (from tensorflow.contrib.learn.python.learn.estimators.linear) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_scores, or set `outputs` argument.
# INFO:tensorflow:Restoring parameters from /var/folders/nl/k74j52jd4bg8_h8gyhg15q_400bvyx/T/tmpaJQtNe/model.ckpt-5000
# [31.193062, 41.855644, 52.51823, 63.180817]
